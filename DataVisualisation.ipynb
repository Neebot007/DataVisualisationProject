# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px
import plotly.graph_objects as go
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# Get the current working directory
current_directory = os.getcwd()

print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: C:\Users\Neeraj  Bhardwaj

# %%
data = pd.read_csv("C:\\Users\\Neeraj  Bhardwaj\\swiggy.csv")
data
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg_ratings  Total_ratings  \
# ...

# %%
data
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg_ratings  Total_ratings  \
# ...

# %%
data[data.Avg_ratings == 3.9]
# Out:
#           ID                     Area       City  \
# 3        248              Indiranagar  Bangalore
# 67      3265              Indiranagar  Bangalore
# 72      3331                   Mumbai     Mumbai
# 85      3914                 Karkhana  Hyderabad
# 87      4064            Koregaon Park       Pune
# ...      ...                      ...        ...
# 8277  400587  Santoshnagar & Saidabad  Hyderabad
# 8322  408977  Santoshnagar & Saidabad  Hyderabad
# 8354  416629              Kodambakkam    Chennai
# 8362  418326                  Kothrud       Pune
# 8400  425357           Himayath Nagar  Hyderabad
#
#                                   Restaurant  Price  Avg_ratings  \
# 3                          New Punjabi Hotel  250.0          3.9
# 67                                 Chaipatty  200.0          3.9
# 72                                   Shabari  400.0          3.9
# 85                              Oh So Stoned  300.0          3.9
# ...

# %%
plt.hist(data.Price, bins = 7, color='red', edgecolor = 'white',orientation='vertical')
plt.title("Distribution of Prices")
plt.xlabel("Price")
# Out:
# Text(0.5, 0, 'Price')

# %%
data1 = data[0:10]

# %%
plt.bar(data1.Area, data1.Price)
plt.xlabel('Area')
plt.title('Price')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.scatter(data.Delivery_time, data.Price, c='red')
#plt.xlim(0,10) # imdb varies from 0 to 10
#plt.ylim(0,100) # audience varies from 0 to 100
plt.title('Scatter plot of Delivery Time and Price')
plt.xlabel('Delivery Time')
plt.ylabel('Price')
plt.show()

# %%
rest_area_counts = data.Area.value_counts()
rest_area_counts = rest_area_counts[0:10]
rest_area_counts
# Out:
# Rohini          257
# Chembur         208
# Kothrud         149
# Andheri East    135
# Navrangpura     132
# Indiranagar     130
# Kurla           129
# Koramangala     124
# Bidhannagar     123
# Ashok Nagar     118
# Name: Area, dtype: int64

# %%
plt.pie(rest_area_counts, labels=rest_area_counts.index.tolist())
plt.show()

# %%
blr=data[data.City=='Bangalore']
ch=data[data.City=='Chennai']
blr = blr.sort_values(by='Avg_ratings')
ch = ch.sort_values(by='Avg_ratings')

# %%
plt.plot(blr.Avg_ratings, blr.Price)
plt.plot(ch.Avg_ratings, ch.Price)
plt.legend(['Bangalore', 'Chennai'])
plt.xlabel('Average Rating')
plt.ylabel('Price')
plt.show()

# %%
sns.distplot(data.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>
